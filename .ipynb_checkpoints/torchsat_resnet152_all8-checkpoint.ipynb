# %%
from torchsat.models.segmentation.unet import UNetResNet

import rasterio as rio
import numpy as np
import os, sys
# add the unet helpers
sys.path.append('../../')
# from test_unet_helpers import *
from utils import variable
from unet_models import unet11_MS

import utils as pyt_utils
from torch.optim import Adam
import torch.backends.cudnn as cudnn
from torch.utils.data import Dataset, DataLoader
from pathlib import Path
from validation import validation_binary
from loss import LossBinary
import json
from torch import nn
import torch
import torch.nn.functional as F

from glob import glob
import time
from sklearn.metrics import roc_auc_score, log_loss, roc_auc_score, roc_curve, auc, f1_score, precision_score, recall_score, precision_recall_fscore_support

# %%
def dice_loss(pred,target):
    numerator = 2 * torch.sum(pred * target)
    denominator = torch.sum(pred + target)
    return 1 - (numerator + 1) / (denominator + 1)

# DICE loss https://forums.fast.ai/t/understanding-the-dice-coefficient/5838
def dice_coeff(pred, target):
    smooth = 1.
    num = pred.size(0)
    m1 = pred.view(num, -1)  # Flatten
    m2 = target.view(num, -1)  # Flatten
    intersection = (m1 * m2).sum()

    return (2. * intersection + smooth) / (m1.sum() + m2.sum() + smooth)

class SoftDiceLoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(SoftDiceLoss, self).__init__()

    def forward(self, logits, targets):
        probs = F.sigmoid(logits) #investigate
        #probs = torch.relu(torch.sign(logits)) # this goes to zero and 1
        num = targets.size(0)  # Number of batches

        #score = dice_coeff(probs, targets)
        #score = 1 - score.sum() / num
        
        score = dice_loss(probs, targets)
        return score


class DG_GT_Dataset(Dataset):
    """Dataset class DG and GT data"""
    
    def __init__(self, data_dir, channels='all', img_transform=None, gt_transform=None, rot=False):
        """ 
        Args:
            data_dir (string): the folder containing the image files
            channels (string): 'all', 'bgr', 'bgrn1', 'bgrn2'; band sets for DG imagery
            img_transform (callable, optional): Optional transform to  be applied to source image data
            gt_transform (callable, optional): Optional transform to  be applied to labeled image data
            x_var (iterable, optional): list of predictor variable names
            land_mask (string, optional): defines whether or not to return land mask
        """
        
        # some sanity checks
        assert os.path.exists(data_dir)
        
        self.gt_files = sorted(glob(data_dir + '/gt*.tif'))
        self.img_files = sorted(glob(data_dir + '/dg*.tif'))
        
        
        print(self.img_files[0])
        print(self.gt_files[0])
        
        self.img_transform = img_transform
        self.gt_transform = gt_transform
        self.dg_bgr = [1,2,4]
        self.dg_bgrn1 = [1,2,4,6]
        self.dg_bgrn2 = [1,2,4,7]
        self.channels = channels
        self.rot = rot
        
        assert len(self.img_files) == len(self.gt_files)
        
    
    def __getitem__(self, idx):
        
        """
            Files are organized as <var_type>_<year>_<month>_t<tileNumber>.tif, e.g., Arson_1992_1_t1
            A single dataset needs to be constructed for a given ignition type, year, month, and tile number
        """
        
        img_file = self.img_files[idx]
        gt_file = self.gt_files[idx]
        
        with rio.open(img_file) as src:
            img_arr = src.read()
            
        # check the channels
        if self.channels == 'bgr':
            img_arr = img_arr[self.dg_bgr, :, :]
        elif self.channels == 'bgrn1':
            img_arr = img_arr[self.dg_bgrn1, :, :]
        elif self.channels == 'bgrn2':
            img_arr = img_arr[self.dg_brgn2, :, :]
        else:
            pass
            
        with rio.open(gt_file) as src:
            gt_arr = src.read()
            
        #print(img_arr.shape, gt_arr.shape)

        # first consider the rotation argument
        if self.rot:
            dg_t = torch.from_numpy(img_arr)
            gt_t = torch.from_numpy(gt_arr)
            
            # get a random number
            rot_p = np.random.random()*100
            
            # do nothing
            if rot_p < 15:
                
                return (dg_t, gt_t)
            
            elif (rot_p >= 15) and (rot_p < 50):
                
                dg_rot = dg_t.transpose(1,2)
                gt_rot = gt_t.transpose(1,2)
                
                return (dg_rot, gt_t)
            
            elif (rot_p >= 50) and (rot_p < 75):
                
                dg_rot = dg_t.flip(1).flip(2)
                gt_rot = gt_t.flip(1).flip(2)
                
                return (dg_rot, gt_rot)
                
            else:
            
                dg_rot = dg_t.transpose(1,2).flip(2) #t90 CCW
                gt_rot = gt_t.transpose(1,2).flip(2)
                
                return(dg_rot, gt_rot)
            


        if (self.img_transform is not None):
            return (self.img_transform(torch.from_numpy(img_arr)), 
                    self.gt_transform(torch.from_numpy(gt_arr)))   
        else:
            return (torch.from_numpy(img_arr), torch.from_numpy(gt_arr)) # return X, Y, Mask (Mask uses LandMask in X-var folder)
            
        
    def __len__(self):
        return len(self.img_files)

# %%
from datetime import datetime

def write_event(log, step: int, **data):
    data['step'] = step
    data['dt'] = datetime.now().isoformat()
    log.write(json.dumps(data, sort_keys=True))
    log.write('\n')
    log.flush()
    
save = lambda ep: torch.save({
        'model': model.state_dict(),
        'epoch': ep,
        'step': step,
    }, str(model_path))

# %%
# need to change this to DICE loss!
#loss = LossBinary(jaccard_weight=args.jaccard_weight)
#criterion = nn.CrossEntropyLoss()

torch.manual_seed(0)
np.random.seed(0)
cudnn.benchmark = False
cudnn.deterministic = True

# %%
# aws paths
train_folder = '../../../tiles/kmeans3_split/tiles_d10000_256x256/train'
test_folder = '../../../tiles/kmeans3_split/tiles_d10000_256x256/test'
val_folder = '../../../tiles/kmeans3_split/tiles_d10000_256x256/val'

# load as 4 band
ps_train_ds = DG_GT_Dataset(train_folder, channels='all')
ps_train_ds_rot = DG_GT_Dataset(train_folder, channels='all', rot=True)

ps_test_ds = DG_GT_Dataset(test_folder, channels='all')
ps_val_ds = DG_GT_Dataset(val_folder, channels='all')
# Out:
# ../../../tiles/kmeans3_split/tiles_d10000_256x256/train/dg_is_00000.tif
# ../../../tiles/kmeans3_split/tiles_d10000_256x256/train/gt_is_00000.tif
# ../../../tiles/kmeans3_split/tiles_d10000_256x256/train/dg_is_00000.tif
# ../../../tiles/kmeans3_split/tiles_d10000_256x256/train/gt_is_00000.tif
# ../../../tiles/kmeans3_split/tiles_d10000_256x256/test/dg_is_00731.tif
# ../../../tiles/kmeans3_split/tiles_d10000_256x256/test/gt_is_00731.tif
# ../../../tiles/kmeans3_split/tiles_d10000_256x256/val/dg_is_00500.tif
# ../../../tiles/kmeans3_split/tiles_d10000_256x256/val/gt_is_00500.tif

# %%
# iterate over some batch sizes
times = []
# batch_sizes = [50, 100, 200,300,400,500,600,700,800,900,1000]
# smaller batch sizes as per https://stats.stackexchange.com/questions/164876/tradeoff-batch-size-vs-number-of-iterations-to-train-a-neural-network
#model = unet11_MS(num_bands=4, pretrained=False)

# set some parameters
lr = 0.001
# lr = 0.01
bsize = 32 # was 32

#ps_model = UNet(in_channels=4, n_classes=1, depth=5, wf=6, padding=True, batch_norm=False, up_mode='upconv')
# ps_model = unet11_MS(num_bands=4, pretrained=False)
ps_model = UNetResNet(encoder_depth=152, num_classes=1, in_channels=8, num_filters=32, dropout_2d=0.2,
                 pretrained=False, is_deconv=True)

ps_optimizer = Adam(ps_model.parameters(), lr=lr)
ps_criterion = LossBinary(jaccard_weight=1.0)
# ps_criterion = SoftDiceLoss()

###### specify DataLoaders
n_workers=4 # for some unknown reason, 0 is enabling all GPUs when 4 had previously done the trick. could be slower.
n_workers=torch.cuda.device_count()*2
ps_train_dl = DataLoader(ps_train_ds, batch_size=bsize, shuffle=True, num_workers=n_workers)
ps_train_rot_dl = DataLoader(ps_train_ds_rot, batch_size=bsize, shuffle=True, num_workers=n_workers)
ps_test_dl = DataLoader(ps_test_ds, batch_size=bsize, shuffle=True, num_workers=n_workers)


# make model parallel and on GPU
# device=torch.device("cpu")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # get device for gpu or cpu
if torch.cuda.device_count() >= 1:
    print("Let's use", torch.cuda.device_count(), "GPUs!")
    ps_model = nn.DataParallel(ps_model)
    ps_model.to(device)
else:
    #ps_model = nn.DataParallel(ps_model)
    print('made cpu parallel')
# Out:
# Let's use 4 GPUs!

# %%
 torch.cuda.device_count()
# Out:
# 4

# %%
print('batchsize, ', bsize)
ps_mean_loss = 0.0
ps_running_loss = 0.0
print('training...')

ps_losses=[]
ps_losses_ep = []
ps_step=0

# record time for one epoch
ps_rocs = []
ps_f1 = []
ps_prec = []
ps_recall = []
ps_f1_ep = []
ps_mAP_ep = []
ps_mAR_ep = []

#####################################################

t0 = time.time()
num_epochs = 500
ctr=0
ps_model.train()
for epoch in range(num_epochs):
    
#     try:
    te = time.time()

    epoch_i = epoch+1
    print('on epoch {}'.format(epoch_i))

    running_loss = 0
    
        
    _ps_rocs = []
    _ps_f1 = []
    _ps_prec = []
    _ps_recall = []
    for i, (inputs_, targets_) in enumerate(ps_train_rot_dl):

        #print('hi')

        # get the inputs
        targets_ = targets_.type(torch.FloatTensor)

        #inputs, targets = variable(inputs_).cuda(), variable(targets_).cuda()
        inputs, targets = variable(inputs_), variable(targets_)
        inputs.to(device)
        targets.to(device)

        outputs = ps_model(inputs)

        # zero parameter gradients
        ps_optimizer.zero_grad()

        # forward + backward + optimize            
        i_loss = ps_criterion(outputs, targets)
        i_loss.backward()
        ps_optimizer.step()
        ps_step+=1

        running_loss += i_loss

        #record iterations f1, precision, recall
        _f1 = f1_score(targets.cpu().data.numpy().flatten(), outputs.cpu().data.numpy().squeeze().flatten() > 0., average='binary')
        _ps_f1.append(_f1)
        _prec = precision_score(targets.cpu().data.numpy().flatten(), outputs.cpu().data.numpy().squeeze().flatten() > 0, average='binary')
        _ps_prec.append(_prec)
        _recall = recall_score(targets.cpu().data.numpy().flatten(), outputs.cpu().data.numpy().squeeze().flatten() > 0, average='binary')
        _ps_recall.append(_recall)

        if i%5 == 0: # print/store every 5
            ps_losses.append(i_loss)
            #running_loss += i_loss
            #print('[%d, %5d] loss: %.3f' %(epoch, i + 1, i_loss))

        # debug break
#             ctr+=1
#             if ctr>50:
#                 break

    # append precision and recall metrics
    ps_f1 += _ps_f1
    ps_prec += _ps_prec
    ps_recall += _ps_recall

    ps_f1_ep.append(np.mean(_ps_f1))
    ps_mAP_ep.append(np.mean(_ps_prec))
    ps_mAR_ep.append(np.mean(_ps_recall))

    # get some numbers for the ROC curve
    if epoch_i%2 == 0:
        pred_y = outputs.cpu().data.numpy().squeeze().flatten()
        target_y = targets.cpu().data.numpy().flatten()
        tu = (i_loss, roc_auc_score(target_y,pred_y ))
        print ('epoch: {}, LOSS={}, ROC_AUC={} '.format(epoch_i, *tu))  
        ps_rocs.append(tu[1])


    ps_losses_ep.append(running_loss)
    te1 = time.time()
    print('time for epoch {}: {} seconds'.format(epoch_i, te1-te))

    # early exit critera
#         if len(ps_rocs)>2:
#             if (np.abs(ps_rocs[-1] - ps_rocs[-2]) < 0.009) and (ps_rocs[-1] > 0.98):
#                 print('area under curve not changing significantly, exit loop')
#                 break_flag = False

#                 if break_flag:
#                     break

#     except Exception as e:
#         print('something happened')
#         print(e)
#         break
    

        
t1 = time.time()
print ('total time: ',t1 - t0)
times.append(t1-t0)
# Out:
# batchsize,  32
# training...
# on epoch 1
# /home/ubuntu/anaconda3/envs/spatial_torch2/lib/python3.6/site-packages/torch/nn/functional.py:1351: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# /home/ubuntu/anaconda3/envs/spatial_torch2/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/ubuntu/anaconda3/envs/spatial_torch2/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# time for epoch 1: 41.0957818031311 seconds
# on epoch 2
# epoch: 2, LOSS=1.1416881084442139, ROC_AUC=0.7033933597604045
# time for epoch 2: 30.02832794189453 seconds
# on epoch 3
# time for epoch 3: 30.467448949813843 seconds
# on epoch 4
# epoch: 4, LOSS=1.2996692657470703, ROC_AUC=0.6950426334604516
# time for epoch 4: 31.45070481300354 seconds
# on epoch 5
# time for epoch 5: 31.049091339111328 seconds
# on epoch 6
# epoch: 6, LOSS=1.3632832765579224, ROC_AUC=0.6940171676727422
# time for epoch 6: 31.12572693824768 seconds
# on epoch 7
# time for epoch 7: 30.65039873123169 seconds
# on epoch 8
# epoch: 8, LOSS=1.399704933166504, ROC_AUC=0.6739100434675109
# time for epoch 8: 31.79427456855774 seconds
# on epoch 9
# time for epoch 9: 30.817497730255127 seconds
# on epoch 10
# epoch: 10, LOSS=1.3377439975738525, ROC_AUC=0.7072214835997708
# time for epoch 10: 31.08651566505432 seconds
# on epoch 11
# time for epoch 11: 31.11394476890564 seconds
# on epoch 12
# epoch: 12, LOSS=1.2031855583190918, ROC_AUC=0.7487779439859513
# time for epoch 12: 31.786163568496704 seconds
# on epoch 13
# time for epoch 13: 30.952280282974243 seconds
# on epoch 14
# epoch: 14, LOSS=1.0660746097564697, ROC_AUC=0.7654747566102621
# time for epoch 14: 31.477726697921753 seconds
# on epoch 15
# time for epoch 15: 30.981034517288208 seconds
# on epoch 16
# epoch: 16, LOSS=0.9635463953018188, ROC_AUC=0.7432618376406753
# time for epoch 16: 32.019177198410034 seconds
# on epoch 17
# time for epoch 17: 31.248733282089233 seconds
# on epoch 18
# epoch: 18, LOSS=0.98924720287323, ROC_AUC=0.7682584401768864
# time for epoch 18: 31.332003831863403 seconds
# on epoch 19
# time for epoch 19: 31.329035997390747 seconds
# on epoch 20
# epoch: 20, LOSS=1.2841196060180664, ROC_AUC=0.7253901453541495
# time for epoch 20: 32.07450604438782 seconds
# on epoch 21
# time for epoch 21: 31.440248727798462 seconds
# on epoch 22
# epoch: 22, LOSS=1.0970094203948975, ROC_AUC=0.7651612085231079
# time for epoch 22: 31.93333387374878 seconds
# on epoch 23
# time for epoch 23: 31.305013179779053 seconds
# on epoch 24
# epoch: 24, LOSS=1.0871425867080688, ROC_AUC=0.7933417320651325
# time for epoch 24: 32.10353398323059 seconds
# on epoch 25
# time for epoch 25: 31.251065731048584 seconds
# on epoch 26
# epoch: 26, LOSS=1.0622637271881104, ROC_AUC=0.7594416348916393
# time for epoch 26: 32.01132273674011 seconds
# on epoch 27
# time for epoch 27: 31.263497352600098 seconds
# on epoch 28
# epoch: 28, LOSS=1.0629918575286865, ROC_AUC=0.7782330742813585
# time for epoch 28: 31.840670585632324 seconds
# on epoch 29
# time for epoch 29: 31.147433042526245 seconds
# on epoch 30
# epoch: 30, LOSS=1.2039426565170288, ROC_AUC=0.7509864614560311
# time for epoch 30: 31.58639359474182 seconds
# on epoch 31
# time for epoch 31: 31.35263419151306 seconds
# on epoch 32
# epoch: 32, LOSS=0.9130875468254089, ROC_AUC=0.8066365531015617
# time for epoch 32: 31.70540189743042 seconds
# on epoch 33
# time for epoch 33: 31.518303394317627 seconds
# on epoch 34
# epoch: 34, LOSS=1.030845284461975, ROC_AUC=0.774832114400704
# time for epoch 34: 31.931540727615356 seconds
# on epoch 35
# time for epoch 35: 31.188769340515137 seconds
# on epoch 36
# epoch: 36, LOSS=1.0256311893463135, ROC_AUC=0.7981107271598388
# time for epoch 36: 31.93925142288208 seconds
# on epoch 37
# time for epoch 37: 31.578028678894043 seconds
# on epoch 38
# epoch: 38, LOSS=1.089849591255188, ROC_AUC=0.7798359564317948
# time for epoch 38: 31.589035749435425 seconds
# on epoch 39
# time for epoch 39: 31.24967098236084 seconds
# on epoch 40
# epoch: 40, LOSS=1.1173195838928223, ROC_AUC=0.7940794890917849
# time for epoch 40: 32.198333501815796 seconds
# on epoch 41
# time for epoch 41: 31.189289808273315 seconds
# on epoch 42
# epoch: 42, LOSS=0.9578911066055298, ROC_AUC=0.8289997301073203
# time for epoch 42: 31.63719892501831 seconds
# on epoch 43
# time for epoch 43: 31.942893505096436 seconds
# on epoch 44
# epoch: 44, LOSS=0.9214696884155273, ROC_AUC=0.8186059495117195
# time for epoch 44: 31.597631454467773 seconds
# on epoch 45
# time for epoch 45: 31.833496570587158 seconds
# on epoch 46
# epoch: 46, LOSS=1.0053479671478271, ROC_AUC=0.8122217967747779
# time for epoch 46: 31.470741033554077 seconds
# on epoch 47
# time for epoch 47: 31.508497714996338 seconds
# on epoch 48
# epoch: 48, LOSS=1.0150126218795776, ROC_AUC=0.8067488121237134
# time for epoch 48: 32.062763929367065 seconds
# on epoch 49
# time for epoch 49: 31.66244077682495 seconds
# on epoch 50
# epoch: 50, LOSS=1.0938098430633545, ROC_AUC=0.8057631351237465
# time for epoch 50: 32.18235182762146 seconds
# on epoch 51
# time for epoch 51: 31.373805046081543 seconds
# on epoch 52
# epoch: 52, LOSS=1.1359597444534302, ROC_AUC=0.7997310007355797
# time for epoch 52: 32.4638409614563 seconds
# on epoch 53
# time for epoch 53: 31.80793571472168 seconds
# on epoch 54
# epoch: 54, LOSS=0.9666551947593689, ROC_AUC=0.8304107929696817
# time for epoch 54: 31.541288137435913 seconds
# on epoch 55
# time for epoch 55: 31.338129997253418 seconds
# on epoch 56
# epoch: 56, LOSS=1.0051751136779785, ROC_AUC=0.8370118537516062
# time for epoch 56: 32.088990449905396 seconds
# on epoch 57
# time for epoch 57: 31.704590797424316 seconds
# on epoch 58
# epoch: 58, LOSS=0.9101914167404175, ROC_AUC=0.8420071596252803
# time for epoch 58: 31.67788052558899 seconds
# on epoch 59
# time for epoch 59: 31.755877256393433 seconds
# on epoch 60
# epoch: 60, LOSS=0.9989181160926819, ROC_AUC=0.8323907174139924
# time for epoch 60: 31.706629991531372 seconds
# on epoch 61
# time for epoch 61: 31.374024152755737 seconds
# on epoch 62
# epoch: 62, LOSS=0.9082037210464478, ROC_AUC=0.8360703216580897
# time for epoch 62: 32.04348015785217 seconds
# on epoch 63
# time for epoch 63: 31.373520612716675 seconds
# on epoch 64
# epoch: 64, LOSS=1.0504639148712158, ROC_AUC=0.8085957158307786
# time for epoch 64: 32.30355954170227 seconds
# on epoch 65
# time for epoch 65: 31.353047132492065 seconds
# on epoch 66
# epoch: 66, LOSS=0.973250687122345, ROC_AUC=0.8320917719119099
# time for epoch 66: 32.31195044517517 seconds
# on epoch 67
# time for epoch 67: 31.25009512901306 seconds
# on epoch 68
# epoch: 68, LOSS=1.0221792459487915, ROC_AUC=0.8230962405791463
# time for epoch 68: 31.92853546142578 seconds
# on epoch 69
# time for epoch 69: 31.658836603164673 seconds
# on epoch 70
# epoch: 70, LOSS=0.8324145078659058, ROC_AUC=0.8586942120270146
# time for epoch 70: 32.212647438049316 seconds
# on epoch 71
# time for epoch 71: 31.951929807662964 seconds
# on epoch 72
# epoch: 72, LOSS=0.8233518004417419, ROC_AUC=0.8668120683658666
# time for epoch 72: 32.24701404571533 seconds
# on epoch 73
# time for epoch 73: 31.86541438102722 seconds
# on epoch 74
# epoch: 74, LOSS=0.8661316633224487, ROC_AUC=0.8449199236936664
# time for epoch 74: 32.45484447479248 seconds
# on epoch 75
# time for epoch 75: 31.518394947052002 seconds
# on epoch 76
# epoch: 76, LOSS=0.9045188426971436, ROC_AUC=0.8397974791291509
# time for epoch 76: 32.42396593093872 seconds
# on epoch 77
# time for epoch 77: 31.491669416427612 seconds
# on epoch 78
# epoch: 78, LOSS=0.9980820417404175, ROC_AUC=0.8168663747643287
# time for epoch 78: 32.27638912200928 seconds
# on epoch 79
# time for epoch 79: 31.63675880432129 seconds
# on epoch 80
# epoch: 80, LOSS=0.8406196236610413, ROC_AUC=0.8581415385538448
# time for epoch 80: 31.862014532089233 seconds
# on epoch 81
# time for epoch 81: 31.387025833129883 seconds
# on epoch 82
# epoch: 82, LOSS=0.8452194929122925, ROC_AUC=0.8663309596733663
# time for epoch 82: 32.54259896278381 seconds
# on epoch 83
# time for epoch 83: 31.458042860031128 seconds
# on epoch 84
# epoch: 84, LOSS=0.813980221748352, ROC_AUC=0.8653105172848159
# time for epoch 84: 31.82164740562439 seconds
# on epoch 85
# time for epoch 85: 31.63090491294861 seconds
# on epoch 86
# epoch: 86, LOSS=0.8077644109725952, ROC_AUC=0.8784410776830662
# time for epoch 86: 31.933164596557617 seconds
# on epoch 87
# time for epoch 87: 31.585253953933716 seconds
# on epoch 88
# epoch: 88, LOSS=0.8273990154266357, ROC_AUC=0.863035018908604
# time for epoch 88: 32.487765312194824 seconds
# on epoch 89
# time for epoch 89: 31.442969799041748 seconds
# on epoch 90
# epoch: 90, LOSS=0.803215742111206, ROC_AUC=0.8617349740603446
# time for epoch 90: 31.934841632843018 seconds
# on epoch 91
# time for epoch 91: 31.52739453315735 seconds
# on epoch 92
# epoch: 92, LOSS=0.8155273199081421, ROC_AUC=0.8751907594099902
# time for epoch 92: 31.84888768196106 seconds
# on epoch 93
# time for epoch 93: 31.58332586288452 seconds
# on epoch 94
# epoch: 94, LOSS=0.8483372926712036, ROC_AUC=0.8561831768209069
# time for epoch 94: 31.923187732696533 seconds
# on epoch 95
# time for epoch 95: 31.928694486618042 seconds
# on epoch 96
# epoch: 96, LOSS=0.945504367351532, ROC_AUC=0.85581601519737
# time for epoch 96: 32.6473445892334 seconds
# on epoch 97
# time for epoch 97: 31.696839332580566 seconds
# on epoch 98
# epoch: 98, LOSS=1.0532701015472412, ROC_AUC=0.840296411246307
# time for epoch 98: 31.954241514205933 seconds
# on epoch 99
# time for epoch 99: 31.650489568710327 seconds
# on epoch 100
# epoch: 100, LOSS=0.8516823053359985, ROC_AUC=0.8696661000178825
# time for epoch 100: 31.93047595024109 seconds
# on epoch 101
# time for epoch 101: 31.8880398273468 seconds
# on epoch 102
# epoch: 102, LOSS=0.8962235450744629, ROC_AUC=0.8661290161106735
# time for epoch 102: 32.423582553863525 seconds
# on epoch 103
# time for epoch 103: 31.67952561378479 seconds
# on epoch 104
# epoch: 104, LOSS=0.761559009552002, ROC_AUC=0.8773578257360499
# time for epoch 104: 32.09227013587952 seconds
# on epoch 105
# time for epoch 105: 32.05673694610596 seconds
# on epoch 106
# epoch: 106, LOSS=0.8093105554580688, ROC_AUC=0.8776795252673428
# time for epoch 106: 32.3424015045166 seconds
# on epoch 107
# time for epoch 107: 32.0438232421875 seconds
# on epoch 108
# epoch: 108, LOSS=0.7893439531326294, ROC_AUC=0.8847812118667923
# time for epoch 108: 32.03053593635559 seconds
# on epoch 109
# time for epoch 109: 31.749011993408203 seconds
# on epoch 110
# epoch: 110, LOSS=0.905166745185852, ROC_AUC=0.8516628550253158
# time for epoch 110: 32.835477352142334 seconds
# on epoch 111
# time for epoch 111: 31.652384519577026 seconds
# on epoch 112
# epoch: 112, LOSS=0.8167514204978943, ROC_AUC=0.8760078141121516
# time for epoch 112: 32.070173025131226 seconds
# on epoch 113
# time for epoch 113: 31.877018213272095 seconds
# on epoch 114
# epoch: 114, LOSS=0.8419920206069946, ROC_AUC=0.8750620287219182
# time for epoch 114: 32.27024698257446 seconds
# on epoch 115
# time for epoch 115: 31.610671043395996 seconds
# on epoch 116
# epoch: 116, LOSS=0.7006517648696899, ROC_AUC=0.8942452188438672
# time for epoch 116: 32.408382415771484 seconds
# on epoch 117
# time for epoch 117: 32.34639096260071 seconds
# on epoch 118
# epoch: 118, LOSS=0.7760000228881836, ROC_AUC=0.8887989299302507
# time for epoch 118: 32.250648021698 seconds
# on epoch 119
# time for epoch 119: 32.54992866516113 seconds
# on epoch 120
# epoch: 120, LOSS=0.8189400434494019, ROC_AUC=0.8805093905119792
# time for epoch 120: 32.488234996795654 seconds
# on epoch 121
# time for epoch 121: 32.154343605041504 seconds
# on epoch 122
# epoch: 122, LOSS=0.8249448537826538, ROC_AUC=0.8825857042527387
# time for epoch 122: 32.09269690513611 seconds
# on epoch 123
# time for epoch 123: 31.961946487426758 seconds
# on epoch 124
# epoch: 124, LOSS=0.7434033751487732, ROC_AUC=0.8944727962282646
# time for epoch 124: 32.76236891746521 seconds
# on epoch 125
# time for epoch 125: 31.99603009223938 seconds
# on epoch 126
# epoch: 126, LOSS=0.7550061941146851, ROC_AUC=0.8787828400705983
# time for epoch 126: 32.70915722846985 seconds
# on epoch 127
# time for epoch 127: 32.3911988735199 seconds
# on epoch 128
# epoch: 128, LOSS=0.8828928470611572, ROC_AUC=0.86643396500019
# time for epoch 128: 32.19004511833191 seconds
# on epoch 129
# time for epoch 129: 31.970770597457886 seconds
# on epoch 130
# epoch: 130, LOSS=0.7245625853538513, ROC_AUC=0.9080748868771605
# time for epoch 130: 32.34653353691101 seconds
# on epoch 131
# time for epoch 131: 32.04591631889343 seconds
# on epoch 132
# epoch: 132, LOSS=0.7082037925720215, ROC_AUC=0.9047451070155558
# time for epoch 132: 32.49244809150696 seconds
# on epoch 133
# time for epoch 133: 32.06858539581299 seconds
# on epoch 134
# epoch: 134, LOSS=0.7946239709854126, ROC_AUC=0.8885571721970803
# time for epoch 134: 32.834017276763916 seconds
# on epoch 135
# time for epoch 135: 31.99168038368225 seconds
# on epoch 136
# epoch: 136, LOSS=0.802088737487793, ROC_AUC=0.8962133906004218
# time for epoch 136: 32.37550449371338 seconds
# on epoch 137
# time for epoch 137: 32.46113181114197 seconds
# on epoch 138
# epoch: 138, LOSS=0.6964326500892639, ROC_AUC=0.9098378209961893
# time for epoch 138: 32.77009344100952 seconds
# on epoch 139
# time for epoch 139: 32.53047513961792 seconds
# on epoch 140
# epoch: 140, LOSS=0.8317054510116577, ROC_AUC=0.8920275902990387
# time for epoch 140: 32.386154890060425 seconds
# on epoch 141
# time for epoch 141: 32.61208510398865 seconds
# on epoch 142
# epoch: 142, LOSS=0.7827038764953613, ROC_AUC=0.8979365014257839
# time for epoch 142: 32.30718660354614 seconds
# on epoch 143
# time for epoch 143: 32.60312104225159 seconds
# on epoch 144
# epoch: 144, LOSS=0.793707013130188, ROC_AUC=0.8915544759972923
# time for epoch 144: 32.342291593551636 seconds
# on epoch 145
# time for epoch 145: 32.176976680755615 seconds
# on epoch 146
# epoch: 146, LOSS=0.7145582437515259, ROC_AUC=0.9077958021842183
# time for epoch 146: 32.57975387573242 seconds
# on epoch 147
# time for epoch 147: 32.60642862319946 seconds
# on epoch 148
# epoch: 148, LOSS=0.7867045402526855, ROC_AUC=0.8970725710344403
# time for epoch 148: 32.15149474143982 seconds
# on epoch 149
# time for epoch 149: 32.4462616443634 seconds
# on epoch 150
# epoch: 150, LOSS=0.676385760307312, ROC_AUC=0.9149267258194249
# time for epoch 150: 32.99729561805725 seconds
# on epoch 151
# time for epoch 151: 32.669941902160645 seconds
# on epoch 152
# epoch: 152, LOSS=0.7121918201446533, ROC_AUC=0.9112718452741397
# time for epoch 152: 32.82072710990906 seconds
# on epoch 153
# time for epoch 153: 32.50142478942871 seconds
# on epoch 154
# epoch: 154, LOSS=0.6938285231590271, ROC_AUC=0.9158900226137212
# time for epoch 154: 32.66398596763611 seconds
# on epoch 155
# time for epoch 155: 32.07513189315796 seconds
# on epoch 156
# epoch: 156, LOSS=0.6945560574531555, ROC_AUC=0.9150612567591148
# time for epoch 156: 32.31125569343567 seconds
# on epoch 157
# time for epoch 157: 32.649664640426636 seconds
# on epoch 158
# epoch: 158, LOSS=0.6484707593917847, ROC_AUC=0.9196263506086618
# time for epoch 158: 32.6371111869812 seconds
# on epoch 159
# time for epoch 159: 32.88149452209473 seconds
# on epoch 160
# epoch: 160, LOSS=0.756903350353241, ROC_AUC=0.9093609743218238
# time for epoch 160: 33.058839082717896 seconds
# on epoch 161
# time for epoch 161: 32.17365288734436 seconds
# on epoch 162
# epoch: 162, LOSS=0.6844788789749146, ROC_AUC=0.9103277892763102
# time for epoch 162: 32.52587366104126 seconds
# on epoch 163
# time for epoch 163: 32.184099435806274 seconds
# on epoch 164
# epoch: 164, LOSS=0.6705304980278015, ROC_AUC=0.9216957097921803
# time for epoch 164: 32.47223615646362 seconds
# on epoch 165
# time for epoch 165: 32.30998134613037 seconds
# on epoch 166
# epoch: 166, LOSS=0.7225903272628784, ROC_AUC=0.911043030220858
# time for epoch 166: 32.409910678863525 seconds
# on epoch 167
# time for epoch 167: 32.20456910133362 seconds
# on epoch 168
# epoch: 168, LOSS=0.5601504445075989, ROC_AUC=0.9287605282105578
# time for epoch 168: 32.821598291397095 seconds
# on epoch 169
# time for epoch 169: 32.14822697639465 seconds
# on epoch 170
# epoch: 170, LOSS=0.49063074588775635, ROC_AUC=0.9446923115203545
# time for epoch 170: 32.425344705581665 seconds
# on epoch 171
# time for epoch 171: 32.19426774978638 seconds
# on epoch 172
# epoch: 172, LOSS=0.7652769088745117, ROC_AUC=0.9091053546186287
# time for epoch 172: 32.46800756454468 seconds
# on epoch 173
# time for epoch 173: 32.353346824645996 seconds
# on epoch 174
# epoch: 174, LOSS=0.5716190934181213, ROC_AUC=0.9341912875041601
# time for epoch 174: 32.66384172439575 seconds
# on epoch 175
# time for epoch 175: 32.17640233039856 seconds
# on epoch 176
# epoch: 176, LOSS=0.6769480109214783, ROC_AUC=0.9194661456282538
# time for epoch 176: 32.55205154418945 seconds
# on epoch 177
# time for epoch 177: 32.144261598587036 seconds
# on epoch 178
# epoch: 178, LOSS=0.6754578948020935, ROC_AUC=0.9247474981369962
# time for epoch 178: 32.57206702232361 seconds
# on epoch 179
# time for epoch 179: 32.18063688278198 seconds
# on epoch 180
# epoch: 180, LOSS=0.6090512275695801, ROC_AUC=0.9326609944098466
# time for epoch 180: 32.991119146347046 seconds
# on epoch 181
# time for epoch 181: 32.42831873893738 seconds
# on epoch 182
# epoch: 182, LOSS=0.660912036895752, ROC_AUC=0.9284381856531161
# time for epoch 182: 32.63170123100281 seconds
# on epoch 183
# time for epoch 183: 32.72520589828491 seconds
# on epoch 184
# epoch: 184, LOSS=0.6886498332023621, ROC_AUC=0.919394435686542
# time for epoch 184: 33.0395884513855 seconds
# on epoch 185
# time for epoch 185: 32.169371366500854 seconds
# on epoch 186
# epoch: 186, LOSS=0.6809310913085938, ROC_AUC=0.9226644185382469
# time for epoch 186: 33.016639947891235 seconds
# on epoch 187
# time for epoch 187: 32.78115177154541 seconds
# on epoch 188
# epoch: 188, LOSS=0.7200580835342407, ROC_AUC=0.9113349444043446
# time for epoch 188: 32.42788100242615 seconds
# on epoch 189
# time for epoch 189: 32.78637146949768 seconds
# on epoch 190
# epoch: 190, LOSS=0.6166678667068481, ROC_AUC=0.9274236469848339
# time for epoch 190: 33.46180009841919 seconds
# on epoch 191
# time for epoch 191: 32.62866830825806 seconds
# on epoch 192
# epoch: 192, LOSS=0.6795241832733154, ROC_AUC=0.9183585086347885
# time for epoch 192: 32.655839681625366 seconds
# on epoch 193
# time for epoch 193: 32.8182737827301 seconds
# on epoch 194
# epoch: 194, LOSS=0.6244661808013916, ROC_AUC=0.9307608030460244
# time for epoch 194: 33.37450933456421 seconds
# on epoch 195
# time for epoch 195: 32.9695680141449 seconds
# on epoch 196
# epoch: 196, LOSS=0.6058133840560913, ROC_AUC=0.9367232601932148
# time for epoch 196: 32.69740033149719 seconds
# on epoch 197
# time for epoch 197: 32.93843650817871 seconds
# on epoch 198
# epoch: 198, LOSS=0.6669769287109375, ROC_AUC=0.9266168882589038
# time for epoch 198: 32.90378189086914 seconds
# on epoch 199
# time for epoch 199: 32.83805584907532 seconds
# on epoch 200
# epoch: 200, LOSS=0.6856305599212646, ROC_AUC=0.9221679684007709
# time for epoch 200: 33.16110634803772 seconds
# on epoch 201
# time for epoch 201: 32.904385566711426 seconds
# on epoch 202
# epoch: 202, LOSS=0.6638474464416504, ROC_AUC=0.9269432585231068
# time for epoch 202: 32.678170919418335 seconds
# on epoch 203
# time for epoch 203: 32.8069703578949 seconds
# on epoch 204
# epoch: 204, LOSS=0.5430269837379456, ROC_AUC=0.9415485601440634
# time for epoch 204: 33.23014497756958 seconds
# on epoch 205
# time for epoch 205: 32.78342127799988 seconds
# on epoch 206
# epoch: 206, LOSS=0.6250079870223999, ROC_AUC=0.9377881987595704
# time for epoch 206: 32.597010374069214 seconds
# on epoch 207
# time for epoch 207: 32.878387689590454 seconds
# on epoch 208
# epoch: 208, LOSS=0.6376998424530029, ROC_AUC=0.9364872016609918
# time for epoch 208: 32.8487753868103 seconds
# on epoch 209
# time for epoch 209: 32.565964221954346 seconds
# on epoch 210
# epoch: 210, LOSS=0.6010297536849976, ROC_AUC=0.9367277533193439
# time for epoch 210: 32.945636510849 seconds
# on epoch 211
# time for epoch 211: 33.16456842422485 seconds
# on epoch 212
# epoch: 212, LOSS=0.6295909881591797, ROC_AUC=0.932123453785267
# time for epoch 212: 33.25532126426697 seconds
# on epoch 213
# time for epoch 213: 32.93802785873413 seconds
# on epoch 214
# epoch: 214, LOSS=0.6368186473846436, ROC_AUC=0.9296421743012893
# time for epoch 214: 32.74197006225586 seconds
# on epoch 215
# time for epoch 215: 32.86719584465027 seconds
# on epoch 216
# epoch: 216, LOSS=0.6550002098083496, ROC_AUC=0.9320107223007268
# time for epoch 216: 32.78477907180786 seconds
# on epoch 217
# time for epoch 217: 33.0858941078186 seconds
# on epoch 218
# epoch: 218, LOSS=0.5753121972084045, ROC_AUC=0.9404051878610773
# time for epoch 218: 33.008527755737305 seconds
# on epoch 219
# time for epoch 219: 32.47979545593262 seconds
# on epoch 220
# epoch: 220, LOSS=0.6281964778900146, ROC_AUC=0.9315563717475459
# time for epoch 220: 32.831889152526855 seconds
# on epoch 221
# time for epoch 221: 32.7080180644989 seconds
# on epoch 222
# epoch: 222, LOSS=0.6141559481620789, ROC_AUC=0.9364127287311951
# time for epoch 222: 33.22565245628357 seconds
# on epoch 223
# time for epoch 223: 32.56772804260254 seconds
# on epoch 224
# epoch: 224, LOSS=0.6109273433685303, ROC_AUC=0.9381164564351459
# time for epoch 224: 33.53657364845276 seconds
# on epoch 225
# time for epoch 225: 33.198259353637695 seconds
# on epoch 226
# epoch: 226, LOSS=0.6175191402435303, ROC_AUC=0.9360385387261485
# time for epoch 226: 33.272846937179565 seconds
# on epoch 227
# time for epoch 227: 33.15419936180115 seconds
# on epoch 228
# epoch: 228, LOSS=0.6268349289894104, ROC_AUC=0.9281985188651412
# time for epoch 228: 32.857630014419556 seconds
# on epoch 229
# time for epoch 229: 32.65943241119385 seconds
# on epoch 230
# epoch: 230, LOSS=0.7273687124252319, ROC_AUC=0.915249166366388
# time for epoch 230: 32.80506873130798 seconds
# on epoch 231
# time for epoch 231: 32.72193193435669 seconds
# on epoch 232
# epoch: 232, LOSS=0.7406394481658936, ROC_AUC=0.9162514026991531
# time for epoch 232: 33.3994574546814 seconds
# on epoch 233
# time for epoch 233: 32.55614233016968 seconds
# on epoch 234
# epoch: 234, LOSS=0.6966515779495239, ROC_AUC=0.918866862716262
# time for epoch 234: 32.943360805511475 seconds
# on epoch 235
# time for epoch 235: 32.28654646873474 seconds
# on epoch 236
# epoch: 236, LOSS=0.6044079065322876, ROC_AUC=0.9365594412313951
# time for epoch 236: 33.42585039138794 seconds
# on epoch 237
# time for epoch 237: 33.14312505722046 seconds
# on epoch 238
# epoch: 238, LOSS=0.5013535618782043, ROC_AUC=0.9518438377729321
# time for epoch 238: 33.42145371437073 seconds
# on epoch 239
# time for epoch 239: 32.77403521537781 seconds
# on epoch 240
# epoch: 240, LOSS=0.5144882202148438, ROC_AUC=0.948155452806108
# time for epoch 240: 33.68186902999878 seconds
# on epoch 241
# time for epoch 241: 33.217801094055176 seconds
# on epoch 242
# epoch: 242, LOSS=0.509246289730072, ROC_AUC=0.9528467095971159
# time for epoch 242: 32.920907974243164 seconds
# on epoch 243
# time for epoch 243: 32.72337031364441 seconds
# on epoch 244
# epoch: 244, LOSS=0.41744816303253174, ROC_AUC=0.9628713383051746
# time for epoch 244: 32.93386483192444 seconds
# on epoch 245
# time for epoch 245: 33.04957413673401 seconds
# on epoch 246
# epoch: 246, LOSS=0.4995933175086975, ROC_AUC=0.9528476268682731
# time for epoch 246: 33.16963744163513 seconds
# on epoch 247
# time for epoch 247: 32.78377413749695 seconds
# on epoch 248
# epoch: 248, LOSS=0.4232446849346161, ROC_AUC=0.9675308345425915
# time for epoch 248: 33.55821990966797 seconds
# on epoch 249
# time for epoch 249: 33.30078101158142 seconds
# on epoch 250
# epoch: 250, LOSS=0.5997569561004639, ROC_AUC=0.9378800193195607
# time for epoch 250: 33.140714168548584 seconds
# on epoch 251
# time for epoch 251: 32.569140911102295 seconds
# on epoch 252
# epoch: 252, LOSS=0.5703786611557007, ROC_AUC=0.9498692099819079
# time for epoch 252: 33.48665642738342 seconds
# on epoch 253
# time for epoch 253: 33.03772306442261 seconds
# on epoch 254
# epoch: 254, LOSS=0.516410231590271, ROC_AUC=0.9516200414914597
# time for epoch 254: 32.95870518684387 seconds
# on epoch 255
# time for epoch 255: 33.29876375198364 seconds
# on epoch 256
# epoch: 256, LOSS=0.5385251045227051, ROC_AUC=0.9524775547935941
# time for epoch 256: 33.28067469596863 seconds
# on epoch 257
# time for epoch 257: 33.16995859146118 seconds
# on epoch 258
# epoch: 258, LOSS=0.5660494565963745, ROC_AUC=0.946662743510042
# time for epoch 258: 33.115227699279785 seconds
# on epoch 259
# time for epoch 259: 33.22593808174133 seconds
# on epoch 260
# epoch: 260, LOSS=0.4957929849624634, ROC_AUC=0.9569250923454654
# time for epoch 260: 33.402184009552 seconds
# on epoch 261
# time for epoch 261: 32.69657063484192 seconds
# on epoch 262
# epoch: 262, LOSS=0.5080580711364746, ROC_AUC=0.9551595757645525
# time for epoch 262: 32.832619190216064 seconds
# on epoch 263
# time for epoch 263: 33.27569580078125 seconds
# on epoch 264
# epoch: 264, LOSS=0.5309078693389893, ROC_AUC=0.9506899450412175
# time for epoch 264: 33.555628061294556 seconds
# on epoch 265
# time for epoch 265: 33.27081370353699 seconds
# on epoch 266
# epoch: 266, LOSS=0.5452343821525574, ROC_AUC=0.9517744009043339
# time for epoch 266: 33.79733443260193 seconds
# on epoch 267
# time for epoch 267: 32.80432319641113 seconds
# on epoch 268
# epoch: 268, LOSS=0.4802362322807312, ROC_AUC=0.9584178156140113
# time for epoch 268: 33.80919098854065 seconds
# on epoch 269
# time for epoch 269: 33.55889081954956 seconds
# on epoch 270
# epoch: 270, LOSS=0.5986541509628296, ROC_AUC=0.9423377027184898
# time for epoch 270: 33.17357349395752 seconds
# on epoch 271
# time for epoch 271: 33.44862985610962 seconds
# on epoch 272
# epoch: 272, LOSS=0.49914318323135376, ROC_AUC=0.954756078258642
# time for epoch 272: 33.4639732837677 seconds
# on epoch 273
# time for epoch 273: 33.701274156570435 seconds
# on epoch 274
# epoch: 274, LOSS=0.88025963306427, ROC_AUC=0.881902941272265
# time for epoch 274: 33.286437034606934 seconds
# on epoch 275
# time for epoch 275: 33.29692220687866 seconds
# on epoch 276
# epoch: 276, LOSS=0.6707371473312378, ROC_AUC=0.9255654588375691
# time for epoch 276: 33.24188852310181 seconds
# on epoch 277
# time for epoch 277: 33.40554141998291 seconds
# on epoch 278
# epoch: 278, LOSS=0.5883802175521851, ROC_AUC=0.9362965212491288
# time for epoch 278: 33.688896894454956 seconds
# on epoch 279
# time for epoch 279: 32.91340613365173 seconds
# on epoch 280
# epoch: 280, LOSS=0.5797043442726135, ROC_AUC=0.9438093968713829
# time for epoch 280: 33.65917468070984 seconds
# on epoch 281
# time for epoch 281: 33.07909607887268 seconds
# on epoch 282
# epoch: 282, LOSS=0.5058479309082031, ROC_AUC=0.9504159423292043
# time for epoch 282: 33.41928434371948 seconds
# on epoch 283
# time for epoch 283: 33.4391393661499 seconds
# on epoch 284
# epoch: 284, LOSS=0.6501415371894836, ROC_AUC=0.9363685548743621
# time for epoch 284: 33.71572399139404 seconds
# on epoch 285
# time for epoch 285: 32.98860239982605 seconds
# on epoch 286
# epoch: 286, LOSS=0.5984495282173157, ROC_AUC=0.9407319163439566
# time for epoch 286: 33.33083963394165 seconds
# on epoch 287
# time for epoch 287: 33.34460663795471 seconds
# on epoch 288
# epoch: 288, LOSS=0.5027514696121216, ROC_AUC=0.956680939890061
# time for epoch 288: 33.38300132751465 seconds
# on epoch 289
# time for epoch 289: 33.55799841880798 seconds
# on epoch 290
# epoch: 290, LOSS=0.5401024222373962, ROC_AUC=0.9470860538497785
# time for epoch 290: 33.393219232559204 seconds
# on epoch 291
# time for epoch 291: 33.61751627922058 seconds
# on epoch 292
# epoch: 292, LOSS=0.497227281332016, ROC_AUC=0.9552991450322512
# time for epoch 292: 33.82586359977722 seconds
# on epoch 293
# time for epoch 293: 33.321064472198486 seconds
# on epoch 294
# epoch: 294, LOSS=0.4231005311012268, ROC_AUC=0.9623819981503494
# time for epoch 294: 33.33079528808594 seconds
# on epoch 295
# time for epoch 295: 33.227885007858276 seconds
# on epoch 296
# epoch: 296, LOSS=0.5618665814399719, ROC_AUC=0.9492719886950954
# time for epoch 296: 33.441359519958496 seconds
# on epoch 297
# time for epoch 297: 33.57729649543762 seconds
# on epoch 298
# epoch: 298, LOSS=0.4131103754043579, ROC_AUC=0.9632289165591925
# time for epoch 298: 33.62995266914368 seconds
# on epoch 299
# time for epoch 299: 32.56649875640869 seconds
# on epoch 300
# epoch: 300, LOSS=0.41584593057632446, ROC_AUC=0.9670127816064792
# time for epoch 300: 33.62414240837097 seconds
# on epoch 301
# time for epoch 301: 33.40709567070007 seconds
# on epoch 302
# epoch: 302, LOSS=0.5081720948219299, ROC_AUC=0.9545024958256934
# time for epoch 302: 33.917151927948 seconds
# on epoch 303
# time for epoch 303: 33.44054913520813 seconds
# on epoch 304
# epoch: 304, LOSS=0.47916126251220703, ROC_AUC=0.9588018394188246
# time for epoch 304: 33.68913125991821 seconds
# on epoch 305
# time for epoch 305: 32.88883423805237 seconds
# on epoch 306
# epoch: 306, LOSS=0.5705411434173584, ROC_AUC=0.9464809896749771
# time for epoch 306: 33.599231004714966 seconds
# on epoch 307
# time for epoch 307: 33.716712951660156 seconds
# on epoch 308
# epoch: 308, LOSS=0.47000405192375183, ROC_AUC=0.9604869424050144
# time for epoch 308: 33.579439878463745 seconds
# on epoch 309
# time for epoch 309: 33.28952598571777 seconds
# on epoch 310
# epoch: 310, LOSS=0.47081971168518066, ROC_AUC=0.958850956002339
# time for epoch 310: 33.44788360595703 seconds
# on epoch 311
# time for epoch 311: 33.50097107887268 seconds
# on epoch 312
# epoch: 312, LOSS=0.5646624565124512, ROC_AUC=0.948749008611274
# time for epoch 312: 33.53432369232178 seconds
# on epoch 313
# time for epoch 313: 33.16919445991516 seconds
# on epoch 314
# epoch: 314, LOSS=0.3657330572605133, ROC_AUC=0.9714952775261817
# time for epoch 314: 34.04577994346619 seconds
# on epoch 315
# time for epoch 315: 33.51732420921326 seconds
# on epoch 316
# epoch: 316, LOSS=0.5959702730178833, ROC_AUC=0.9437852770185493
# time for epoch 316: 33.50057029724121 seconds
# on epoch 317
# time for epoch 317: 33.29014539718628 seconds
# on epoch 318
# epoch: 318, LOSS=0.42009249329566956, ROC_AUC=0.9673450087310226
# time for epoch 318: 34.144367933273315 seconds
# on epoch 319
# time for epoch 319: 33.305363178253174 seconds
# on epoch 320
# epoch: 320, LOSS=0.579612135887146, ROC_AUC=0.947543122483897
# time for epoch 320: 33.33985638618469 seconds
# on epoch 321
# time for epoch 321: 33.18783354759216 seconds
# on epoch 322
# epoch: 322, LOSS=0.5015245079994202, ROC_AUC=0.9563154671539822
# time for epoch 322: 33.877116441726685 seconds
# on epoch 323
# time for epoch 323: 33.6732611656189 seconds
# on epoch 324
# epoch: 324, LOSS=0.4450477957725525, ROC_AUC=0.9605919242167501
# time for epoch 324: 33.65094184875488 seconds
# on epoch 325
# time for epoch 325: 32.98478889465332 seconds
# on epoch 326
# epoch: 326, LOSS=0.4343452751636505, ROC_AUC=0.9656084815651809
# time for epoch 326: 33.900524854660034 seconds
# on epoch 327
# time for epoch 327: 33.21105909347534 seconds
# on epoch 328
# epoch: 328, LOSS=0.4920215308666229, ROC_AUC=0.9575181111514042
# time for epoch 328: 33.40666604042053 seconds
# on epoch 329
# time for epoch 329: 33.337584495544434 seconds
# on epoch 330
# epoch: 330, LOSS=0.5680457353591919, ROC_AUC=0.9506351729289486
# time for epoch 330: 34.001243114471436 seconds
# on epoch 331
# time for epoch 331: 33.675965547561646 seconds
# on epoch 332
# epoch: 332, LOSS=0.5474597215652466, ROC_AUC=0.951777400013764
# time for epoch 332: 34.16114592552185 seconds
# on epoch 333
# time for epoch 333: 33.18823766708374 seconds
# on epoch 334
# epoch: 334, LOSS=0.41525566577911377, ROC_AUC=0.9690387591925903
# time for epoch 334: 34.09368634223938 seconds
# on epoch 335
# time for epoch 335: 33.73684811592102 seconds
# on epoch 336
# epoch: 336, LOSS=0.6735090613365173, ROC_AUC=0.9179289461000344
# time for epoch 336: 33.51704478263855 seconds
# on epoch 337
# time for epoch 337: 33.05121994018555 seconds
# on epoch 338
# epoch: 338, LOSS=0.7300498485565186, ROC_AUC=0.9171968071151618
# time for epoch 338: 34.14030146598816 seconds
# on epoch 339
# time for epoch 339: 33.18161463737488 seconds
# on epoch 340
# epoch: 340, LOSS=0.5979969501495361, ROC_AUC=0.9401700206490256
# time for epoch 340: 33.616315841674805 seconds
# on epoch 341
# time for epoch 341: 33.66350865364075 seconds
# on epoch 342
# epoch: 342, LOSS=0.5763678550720215, ROC_AUC=0.9454227137472118
# time for epoch 342: 33.74103832244873 seconds
# on epoch 343
# time for epoch 343: 33.39227366447449 seconds
# on epoch 344
# epoch: 344, LOSS=0.4560854732990265, ROC_AUC=0.9608000257562714
# time for epoch 344: 34.04503917694092 seconds
# on epoch 345
# time for epoch 345: 33.29838037490845 seconds
# on epoch 346
# epoch: 346, LOSS=0.4023764431476593, ROC_AUC=0.967721661174504
# time for epoch 346: 33.712464332580566 seconds
# on epoch 347
# time for epoch 347: 33.822330474853516 seconds
# on epoch 348
# epoch: 348, LOSS=0.47752314805984497, ROC_AUC=0.9591594834301923
# time for epoch 348: 34.11849117279053 seconds
# on epoch 349
# time for epoch 349: 33.37245154380798 seconds
# on epoch 350
# epoch: 350, LOSS=0.3979032635688782, ROC_AUC=0.9664248456006969
# time for epoch 350: 34.135671854019165 seconds
# on epoch 351
# time for epoch 351: 33.536723613739014 seconds
# on epoch 352
# epoch: 352, LOSS=0.5030072331428528, ROC_AUC=0.9573039468210434
# time for epoch 352: 34.0183322429657 seconds
# on epoch 353
# time for epoch 353: 33.519376277923584 seconds
# on epoch 354
# epoch: 354, LOSS=0.4133673310279846, ROC_AUC=0.9668405067282692
# time for epoch 354: 33.72277331352234 seconds
# on epoch 355
# time for epoch 355: 33.67738151550293 seconds
# on epoch 356
# epoch: 356, LOSS=0.4438687264919281, ROC_AUC=0.9615598240445258
# time for epoch 356: 34.04308867454529 seconds
# on epoch 357
# time for epoch 357: 33.99406337738037 seconds
# on epoch 358
# epoch: 358, LOSS=0.5305472612380981, ROC_AUC=0.9531615854146664
# time for epoch 358: 33.678364276885986 seconds
# on epoch 359
# time for epoch 359: 33.50567007064819 seconds
# on epoch 360
# epoch: 360, LOSS=0.505150318145752, ROC_AUC=0.9584391169972751
# time for epoch 360: 33.733163595199585 seconds
# on epoch 361
# time for epoch 361: 33.534602880477905 seconds
# on epoch 362
# epoch: 362, LOSS=0.344642698764801, ROC_AUC=0.9741752423589329
# time for epoch 362: 34.38550519943237 seconds
# on epoch 363
# time for epoch 363: 34.02155566215515 seconds
# on epoch 364
# epoch: 364, LOSS=0.4207635223865509, ROC_AUC=0.9665899021423694
# time for epoch 364: 33.792585372924805 seconds
# on epoch 365
# time for epoch 365: 33.713043212890625 seconds
# on epoch 366
# epoch: 366, LOSS=0.36970388889312744, ROC_AUC=0.9731949295787787
# time for epoch 366: 34.05355930328369 seconds
# on epoch 367
# time for epoch 367: 33.39487409591675 seconds
# on epoch 368
# epoch: 368, LOSS=0.46647214889526367, ROC_AUC=0.9638804739052899
# time for epoch 368: 33.76136064529419 seconds
# on epoch 369
# time for epoch 369: 33.41402626037598 seconds
# on epoch 370
# epoch: 370, LOSS=0.5224570035934448, ROC_AUC=0.9553542397557071
# time for epoch 370: 34.15890717506409 seconds
# on epoch 371
# time for epoch 371: 33.246625661849976 seconds
# on epoch 372
# epoch: 372, LOSS=0.45281827449798584, ROC_AUC=0.9640508084694317
# time for epoch 372: 33.95168972015381 seconds
# on epoch 373
# time for epoch 373: 33.948225259780884 seconds
# on epoch 374
# epoch: 374, LOSS=0.46503329277038574, ROC_AUC=0.9616640633431758
# time for epoch 374: 34.310877561569214 seconds
# on epoch 375
# time for epoch 375: 33.552576541900635 seconds
# on epoch 376
# epoch: 376, LOSS=0.45736730098724365, ROC_AUC=0.9628933976075928
# time for epoch 376: 34.054619789123535 seconds
# on epoch 377
# time for epoch 377: 33.49499297142029 seconds
# on epoch 378
# epoch: 378, LOSS=0.40419822931289673, ROC_AUC=0.9668926463705043
# time for epoch 378: 34.16587734222412 seconds
# on epoch 379
# time for epoch 379: 33.635600328445435 seconds
# on epoch 380
# epoch: 380, LOSS=0.4799894690513611, ROC_AUC=0.9623086269822608
# time for epoch 380: 34.19634675979614 seconds
# on epoch 381
# time for epoch 381: 34.17819857597351 seconds
# on epoch 382
# epoch: 382, LOSS=0.3759085536003113, ROC_AUC=0.9725880597988932
# time for epoch 382: 34.14096665382385 seconds
# on epoch 383
# time for epoch 383: 33.42371106147766 seconds
# on epoch 384
# epoch: 384, LOSS=0.4542659521102905, ROC_AUC=0.9656068772966508
# time for epoch 384: 33.866231203079224 seconds
# on epoch 385
# time for epoch 385: 34.20822286605835 seconds
# on epoch 386
# epoch: 386, LOSS=0.4200300872325897, ROC_AUC=0.9694127340072896
# time for epoch 386: 34.38374376296997 seconds
# on epoch 387
# time for epoch 387: 34.027183532714844 seconds
# on epoch 388
# epoch: 388, LOSS=0.4397231638431549, ROC_AUC=0.9674362513022721
# time for epoch 388: 33.945677518844604 seconds
# on epoch 389
# time for epoch 389: 34.106754302978516 seconds
# on epoch 390
# epoch: 390, LOSS=0.37012654542922974, ROC_AUC=0.9765637648996583
# time for epoch 390: 34.133686780929565 seconds
# on epoch 391
# time for epoch 391: 34.091434478759766 seconds
# on epoch 392
# epoch: 392, LOSS=0.470369815826416, ROC_AUC=0.962620051221121
# time for epoch 392: 34.247995138168335 seconds
# on epoch 393
# time for epoch 393: 34.26550817489624 seconds
# on epoch 394
# epoch: 394, LOSS=0.4265028238296509, ROC_AUC=0.9688311185232898
# time for epoch 394: 34.324300050735474 seconds
# on epoch 395
# time for epoch 395: 33.830395221710205 seconds
# on epoch 396
# epoch: 396, LOSS=0.3722038269042969, ROC_AUC=0.9737324016731951
# time for epoch 396: 34.14150857925415 seconds
# on epoch 397
# time for epoch 397: 33.6861937046051 seconds
# on epoch 398
# epoch: 398, LOSS=0.40734997391700745, ROC_AUC=0.9680901372762315
# time for epoch 398: 34.60310244560242 seconds
# on epoch 399
# time for epoch 399: 33.50963830947876 seconds
# on epoch 400
# epoch: 400, LOSS=0.3332778513431549, ROC_AUC=0.9771286294305896
# time for epoch 400: 34.145055294036865 seconds
# on epoch 401
# time for epoch 401: 34.29833698272705 seconds
# on epoch 402
# epoch: 402, LOSS=0.40847113728523254, ROC_AUC=0.9677474452427379
# time for epoch 402: 34.59145665168762 seconds
# on epoch 403
# time for epoch 403: 33.66892719268799 seconds
# on epoch 404
# epoch: 404, LOSS=0.38187313079833984, ROC_AUC=0.9721341211941075
# time for epoch 404: 34.03301215171814 seconds
# on epoch 405
# time for epoch 405: 34.12399959564209 seconds
# on epoch 406
# epoch: 406, LOSS=0.37663695216178894, ROC_AUC=0.9719791238515297
# time for epoch 406: 34.13604688644409 seconds
# on epoch 407
# time for epoch 407: 33.769604206085205 seconds
# on epoch 408
# epoch: 408, LOSS=0.34952306747436523, ROC_AUC=0.9756766547152156
# time for epoch 408: 33.90267300605774 seconds
# on epoch 409
# time for epoch 409: 33.6325888633728 seconds
# on epoch 410
# epoch: 410, LOSS=0.35998761653900146, ROC_AUC=0.9758563864286405
# time for epoch 410: 34.522640228271484 seconds
# on epoch 411
# time for epoch 411: 33.7507381439209 seconds
# on epoch 412
# epoch: 412, LOSS=0.4044039249420166, ROC_AUC=0.9694974635505736
# time for epoch 412: 33.96413850784302 seconds
# on epoch 413
# time for epoch 413: 33.844743490219116 seconds
# on epoch 414
# epoch: 414, LOSS=0.41079849004745483, ROC_AUC=0.9699348547307776
# time for epoch 414: 34.268447399139404 seconds
# on epoch 415
# time for epoch 415: 34.12442636489868 seconds
# on epoch 416
# epoch: 416, LOSS=0.40512555837631226, ROC_AUC=0.9715281391228825
# time for epoch 416: 34.34185481071472 seconds
# on epoch 417
# time for epoch 417: 33.99959635734558 seconds
# on epoch 418
# epoch: 418, LOSS=0.3881244659423828, ROC_AUC=0.972921461512341
# time for epoch 418: 34.00758481025696 seconds
# on epoch 419
# time for epoch 419: 34.08919143676758 seconds
# on epoch 420
# epoch: 420, LOSS=0.4648002088069916, ROC_AUC=0.9639895754615508
# time for epoch 420: 34.275134563446045 seconds
# on epoch 421
# time for epoch 421: 33.915932416915894 seconds
# on epoch 422
# epoch: 422, LOSS=0.4261605143547058, ROC_AUC=0.9680793664131433
# time for epoch 422: 34.177578926086426 seconds
# on epoch 423
# time for epoch 423: 33.73323106765747 seconds
# on epoch 424
# epoch: 424, LOSS=0.4944734573364258, ROC_AUC=0.9595027788277066
# time for epoch 424: 34.767433643341064 seconds
# on epoch 425
# time for epoch 425: 34.460240602493286 seconds
# on epoch 426
# epoch: 426, LOSS=0.38829320669174194, ROC_AUC=0.974264124567521
# time for epoch 426: 34.43736290931702 seconds
# on epoch 427
# time for epoch 427: 34.40943956375122 seconds
# on epoch 428
# epoch: 428, LOSS=0.3665110468864441, ROC_AUC=0.9762004873497182
# time for epoch 428: 34.34765100479126 seconds
# on epoch 429
# time for epoch 429: 34.699403285980225 seconds
# on epoch 430
# epoch: 430, LOSS=0.3566223382949829, ROC_AUC=0.974503043895117
# time for epoch 430: 34.584760904312134 seconds
# on epoch 431
# time for epoch 431: 34.39523148536682 seconds
# on epoch 432
# epoch: 432, LOSS=0.5715419054031372, ROC_AUC=0.950441829535436
# time for epoch 432: 34.51006746292114 seconds
# on epoch 433
# time for epoch 433: 34.0830180644989 seconds
# on epoch 434
# epoch: 434, LOSS=0.467565655708313, ROC_AUC=0.9645791484611878
# time for epoch 434: 34.3344464302063 seconds
# on epoch 435
# time for epoch 435: 34.258230447769165 seconds
# on epoch 436
# epoch: 436, LOSS=0.36641573905944824, ROC_AUC=0.9749608618235017
# time for epoch 436: 34.45669960975647 seconds
# on epoch 437
# time for epoch 437: 34.463829040527344 seconds
# on epoch 438
# epoch: 438, LOSS=0.3544575273990631, ROC_AUC=0.9778127852672529
# time for epoch 438: 34.40752100944519 seconds
# on epoch 439
# time for epoch 439: 33.92235040664673 seconds
# on epoch 440
# epoch: 440, LOSS=0.36766892671585083, ROC_AUC=0.9749351572281324
# time for epoch 440: 34.28248333930969 seconds
# on epoch 441
# time for epoch 441: 33.98873257637024 seconds
# on epoch 442
# epoch: 442, LOSS=0.40630942583084106, ROC_AUC=0.9691372043158745
# time for epoch 442: 34.51034426689148 seconds
# on epoch 443
# time for epoch 443: 34.756197690963745 seconds
# on epoch 444
# epoch: 444, LOSS=0.4085630178451538, ROC_AUC=0.9709490148283381
# time for epoch 444: 34.25412106513977 seconds
# on epoch 445
# time for epoch 445: 34.52126407623291 seconds
# on epoch 446
# epoch: 446, LOSS=0.3914164900779724, ROC_AUC=0.9723517219111791
# time for epoch 446: 34.899638652801514 seconds
# on epoch 447
# time for epoch 447: 34.444480419158936 seconds
# on epoch 448
# epoch: 448, LOSS=0.32361969351768494, ROC_AUC=0.9800028006455108
# time for epoch 448: 34.78174614906311 seconds
# on epoch 449
# time for epoch 449: 34.47168159484863 seconds
# on epoch 450
# epoch: 450, LOSS=0.40224921703338623, ROC_AUC=0.9688614505030096
# time for epoch 450: 34.927422285079956 seconds
# on epoch 451
# time for epoch 451: 34.47134709358215 seconds
# on epoch 452
# epoch: 452, LOSS=0.4690520763397217, ROC_AUC=0.9654417620703221
# time for epoch 452: 34.21653890609741 seconds
# on epoch 453
# time for epoch 453: 34.651885747909546 seconds
# on epoch 454
# epoch: 454, LOSS=0.3606443703174591, ROC_AUC=0.9727756320518274
# time for epoch 454: 34.46005392074585 seconds
# on epoch 455
# time for epoch 455: 34.526315689086914 seconds
# on epoch 456
# epoch: 456, LOSS=0.4086293578147888, ROC_AUC=0.969629836239249
# time for epoch 456: 34.57377290725708 seconds
# on epoch 457
# time for epoch 457: 34.02694058418274 seconds
# on epoch 458
# epoch: 458, LOSS=0.4672700762748718, ROC_AUC=0.9638356532562469
# time for epoch 458: 34.29980516433716 seconds
# on epoch 459
# time for epoch 459: 34.06108856201172 seconds
# on epoch 460
# epoch: 460, LOSS=0.40936702489852905, ROC_AUC=0.9699216693290147
# time for epoch 460: 34.77247357368469 seconds
# on epoch 461
# time for epoch 461: 34.471872091293335 seconds
# on epoch 462
# epoch: 462, LOSS=0.4529758095741272, ROC_AUC=0.9667307912057416
# time for epoch 462: 34.484896421432495 seconds
# on epoch 463
# time for epoch 463: 33.986494302749634 seconds
# on epoch 464
# epoch: 464, LOSS=0.4402303099632263, ROC_AUC=0.9682424994677934
# time for epoch 464: 34.718717098236084 seconds
# on epoch 465
# time for epoch 465: 34.09179472923279 seconds
# on epoch 466
# epoch: 466, LOSS=0.42231684923171997, ROC_AUC=0.9685324794840853
# time for epoch 466: 34.97439765930176 seconds
# on epoch 467
# time for epoch 467: 33.952716588974 seconds
# on epoch 468
# epoch: 468, LOSS=0.4276714324951172, ROC_AUC=0.9675761333053114
# time for epoch 468: 34.51980471611023 seconds
# on epoch 469
# time for epoch 469: 34.168153285980225 seconds
# on epoch 470
# epoch: 470, LOSS=0.38538044691085815, ROC_AUC=0.9730063271651828
# time for epoch 470: 35.10644507408142 seconds
# on epoch 471
# time for epoch 471: 34.74068593978882 seconds
# on epoch 472
# epoch: 472, LOSS=0.4128332734107971, ROC_AUC=0.969746596093875
# time for epoch 472: 34.89991331100464 seconds
# on epoch 473
# time for epoch 473: 34.20860433578491 seconds
# on epoch 474
# epoch: 474, LOSS=0.33313673734664917, ROC_AUC=0.9797141738110169
# time for epoch 474: 34.40804195404053 seconds
# on epoch 475
# time for epoch 475: 34.38012075424194 seconds
# on epoch 476
# epoch: 476, LOSS=0.4865686893463135, ROC_AUC=0.9627018379074136
# time for epoch 476: 34.889373779296875 seconds
# on epoch 477
# time for epoch 477: 35.092363595962524 seconds
# on epoch 478
# epoch: 478, LOSS=0.3682352304458618, ROC_AUC=0.9745202464018837
# time for epoch 478: 34.82388520240784 seconds
# on epoch 479
# time for epoch 479: 34.81237745285034 seconds
# on epoch 480
# epoch: 480, LOSS=0.3584710955619812, ROC_AUC=0.977011033383802
# time for epoch 480: 34.878026723861694 seconds
# on epoch 481
# time for epoch 481: 34.65747046470642 seconds
# on epoch 482
# epoch: 482, LOSS=0.3814477026462555, ROC_AUC=0.9752282868707033
# time for epoch 482: 34.60628390312195 seconds
# on epoch 483
# time for epoch 483: 34.11725091934204 seconds
# on epoch 484
# epoch: 484, LOSS=0.4264299273490906, ROC_AUC=0.9694698068008184
# time for epoch 484: 34.48760986328125 seconds
# on epoch 485
# time for epoch 485: 34.90202260017395 seconds
# on epoch 486
# epoch: 486, LOSS=0.3324984014034271, ROC_AUC=0.9781691303209101
# time for epoch 486: 35.1146125793457 seconds
# on epoch 487
# time for epoch 487: 34.667731046676636 seconds
# on epoch 488
# epoch: 488, LOSS=0.30659717321395874, ROC_AUC=0.9821064177667652
# time for epoch 488: 34.53639817237854 seconds
# on epoch 489
# time for epoch 489: 34.01467943191528 seconds
# on epoch 490
# epoch: 490, LOSS=0.3220735788345337, ROC_AUC=0.9793411276823675
# time for epoch 490: 34.67237424850464 seconds
# on epoch 491
# time for epoch 491: 34.657249450683594 seconds
# on epoch 492
# epoch: 492, LOSS=0.4628293514251709, ROC_AUC=0.9652634123681314
# time for epoch 492: 34.78453540802002 seconds
# on epoch 493
# time for epoch 493: 34.220112323760986 seconds
# on epoch 494
# epoch: 494, LOSS=0.3934871256351471, ROC_AUC=0.973104469028434
# time for epoch 494: 35.26464653015137 seconds
# on epoch 495
# time for epoch 495: 34.75611901283264 seconds
# on epoch 496
# epoch: 496, LOSS=0.40982741117477417, ROC_AUC=0.9719695665934963
# time for epoch 496: 34.33170819282532 seconds
# on epoch 497
# time for epoch 497: 34.33781695365906 seconds
# on epoch 498
# epoch: 498, LOSS=0.5370451211929321, ROC_AUC=0.9480904548201848
# time for epoch 498: 34.804654121398926 seconds
# on epoch 499
# time for epoch 499: 34.26371622085571 seconds
# on epoch 500
# epoch: 500, LOSS=0.5468924641609192, ROC_AUC=0.9448252617239158
# time for epoch 500: 34.50501084327698 seconds
# total time:  16550.219502449036

# %%
from matplotlib import pyplot as plt

plt.plot(ps_losses)
plt.title('losses')
plt.show()

plt.plot(ps_rocs)
plt.title('rocs')
plt.show()

plt.plot(ps_losses_ep)
plt.title('epoch losses')
plt.show()

plt.plot(ps_f1_ep)
plt.title('epoch f1')
plt.show()

plt.plot(ps_mAP_ep)
plt.title('epoch mAP')
plt.show()

plt.plot(ps_mAR_ep)
plt.title('epoch mAR')
plt.show()

# %%
save_res = True

if save_res:
    # directory
    save_dir = 'files_MS_aug_all8'
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # save the model
    model_path = 'jstars_all8_ms_aug_ep{}_step{}_b{}.pt'.format(num_epochs, ps_step, bsize)
    model_path = os.path.join(save_dir, model_path)
    save = lambda ep: torch.save({
            'model': ps_model.state_dict(),
            'epoch': ep,
            'step': ps_step,
        }, str(model_path))

    save(model_path)

    # save the AUCs
    auc_path = 'auc_all8_ms_aug_ep{}_step{}_b{}.txt'.format(num_epochs, ps_step, bsize)
    auc_path = os.path.join(save_dir, auc_path)
    np.savetxt(auc_path, np.array(ps_rocs))

    #save the loss vectors
    ep_loss_path = 'losses_ep_all8_ms_aug_ep{}_step{}_b{}.txt'.format(num_epochs, ps_step, bsize)
    ep_loss_path = os.path.join(save_dir, ep_loss_path)
    np.savetxt(ep_loss_path, np.array(ps_losses_ep))

    #save the total loss vector
    loss_path = 'loss_all8_ms_aug_ep{}_step{}_b{}.txt'.format(num_epochs, ps_step, bsize)
    loss_path = os.path.join(save_dir, loss_path)
    np.savetxt(loss_path, np.array(ps_losses))
    
    # save the f1's
    f1_path = 'f1_all8_ms_aug_ep{}_step{}_b{}.txt'.format(num_epochs, ps_step, bsize)
    f1_path = os.path.join(save_dir, f1_path)
    np.savetxt(loss_path, np.array(ps_f1_ep))
    
    # save the f1's
    f1_path = 'f1_all8_ms_aug_ep{}_step{}_b{}.txt'.format(num_epochs, ps_step, bsize)
    f1_path = os.path.join(save_dir, f1_path)
    np.savetxt(f1_path, np.array(ps_f1_ep))
    
    # save the mAPs
    mAP_path = 'mAP_all8_ms_aug_ep{}_step{}_b{}.txt'.format(num_epochs, ps_step, bsize)
    mAP_path = os.path.join(save_dir, mAP_path)
    np.savetxt(mAP_path, np.array(ps_mAP_ep))
    
    # save the mARs
    mAR_path = 'mAR_all8_ms_aug_ep{}_step{}_b{}.txt'.format(num_epochs, ps_step, bsize)
    mAR_path = os.path.join(save_dir, mAR_path)
    np.savetxt(mAR_path, np.array(ps_mAR_ep))

# %%
ps_model.eval()
for ind in range(0,10):
    fig, ax = plt.subplots(1,3, figsize=(10,5))
    test_im, test_target = ps_test_ds[ind]
    test_out = ps_model(variable(test_im.unsqueeze(0)))
    ax[0].imshow(test_target.numpy()[0])

    out = test_out.cpu().detach().numpy()[0][0]
    ax[1].imshow(out)

    ax[2].imshow(out>0)
    #ax[2].imshow(test_im.unsqueeze(0).cpu().detach().numpy()[0][0])
    plt.show()
    
    false_positive_rate, true_positive_rate, thresholds = roc_curve(test_target.numpy().flatten(), out.flatten())
    roc_auc = auc(false_positive_rate, true_positive_rate)
    plt.plot(false_positive_rate, true_positive_rate)
    plt.title('AUC: {}'.format(roc_auc))
